# %%
 ###https://www.kayak.fr/flights/CDG-MAD/2023-11-22/2023-11-29?sort=bestflight_a

# %% [markdown]
# # kayak.fr

# %% [markdown]
# ## Import

# %%
# Scrappe and Clean
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta


import pandas as pd 
import numpy as np 


from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# ## Scrappe

# %%
ua = UserAgent()
user_agent = ua.random

villes = ["PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD","BER",  "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')

all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date = datetime(2023, 11, 28)

# Boucle sur les semaines
while start_date <= end_date_final:
    for i in range(0, len(villes), 2):
        ville1 = villes[i]
        ville2 = villes[i + 1]

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')

                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            time.sleep(10)
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(2)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(2)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')


        for voyage in voyages:
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)

print('Fin du scraping')
# Out:
# Début scrape des villes PAR et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 31 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 44 €
# Compagnie de vol: Ryanair, Vueling
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes MAD et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 62 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 22:00 – 23:35
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 57 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 69 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 68 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 74 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes LIS et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 07:45 – 16:10
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 7h 25min
# Prix: 133 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 166 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 17:25 – 21:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 170 €
# Compagnie de vol: Vueling
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 181 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 19:30 – 23:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 192 €
# Compagnie de vol: Transavia, Vueling
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 201 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 15:25 – 19:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 218 €
# Compagnie de vol: KLM
# ========================================
# Début scrape des villes BRU et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol: Aer Lingus, Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 90 €
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 18:55 – 19:40
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 150 €
# Compagnie de vol: Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes CPH et OSL pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3.2\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 28
#      24 ville2 = villes[i + 1]
#      26 print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')
# ---> 28 driver = webdriver.Firefox(options=options)
#      29 try:
#      30     driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:60, in WebDriver.__init__(self, options, service, keep_alive)
#      57 options = options if options else Options()
#      59 self.service.path = DriverFinder.get_path(self.service, options)
# ---> 60 self.service.start()
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     ignore_proxy=options._ignore_local_proxy,
#      65     keep_alive=keep_alive,
#      66 )
#      67 super().__init__(command_executor=executor, options=options)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:103, in Service.start(self)
#     101 while True:
#     102     self.assert_process_still_running()
# --> 103     if self.is_connectable():
#     104         break
#     106     count += 1
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:120, in Service.is_connectable(self)
#     117 def is_connectable(self) -> bool:
#     118     """Establishes a socket connection to determine if the service running
#     119     on the port is accessible."""
# --> 120     return utils.is_connectable(self.port)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\utils.py:101, in is_connectable(port, host)
#      99 socket_ = None
#     100 try:
# --> 101     socket_ = socket.create_connection((host, port), 1)
#     102     result = True
#     103 except _is_connectable_exceptions:
#
# File ~\anaconda3.2\Lib\socket.py:843, in create_connection(address, timeout, source_address, all_errors)
#     841 except error as exc:
#     842     if not all_errors:
# --> 843         exceptions.clear()  # raise only the last error
#     844     exceptions.append(exc)
#     845     if sock is not None:
#
# KeyboardInterrupt:

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException

def action_aleatoire(driver):
    actions_possibles = ["scroll", "click_button", "fill_text"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "click_button":
        # Action aléatoire : Cliquez sur un élément aléatoire (par exemple, un bouton de tri)
        wait = WebDriverWait(driver, 10)
        elements = wait.until(EC.presence_of_all_elements_located((By.XPATH, ".//button[@class='Iqt3 Iqt3-mod-bold Button-No-Standard-Style Iqt3-mod-variant-outline Iqt3-mod-theme-none Iqt3-mod-shape-rounded-small Iqt3-mod-shape-mod-default Iqt3-mod-spacing-default Iqt3-mod-size-default']")))
        
        if elements:
            random_button = random.choice(elements)
            try:
                random_button.click()
            except ElementClickInterceptedException:
                pass  # Gérer l'exception, par exemple, en ne faisant rien

    elif action_choisie == "fill_text":
        # Action aléatoire : Remplissez un champ de texte (par exemple, une recherche)
        wait = WebDriverWait(driver, 10)
        try:
            search_input = wait.until(EC.visibility_of_element_located((By.XPATH, ".//input[@class='k_my-input']")))
            search_terms = ["Amsterdam", "Brussels", "Dublin", "Berlin", "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Reykjavik", "Moscow", "Warsaw", "Paris", "Rome", "Madrid", "London", "Lisbon", "Prague", "Budapest", "Vienna", "Athens", "Bucharest", "Sofia", "Belgrade", "Zagreb", "Tirana", "Skopje", "Podgorica", "Pristina", "Tallinn", "Riga", "Vilnius", "Chișinău", "Minsk", "Kyiv", "Tbilisi", "Yerevan", "Baku", "Ankara", "Ercan", "Valletta", "Vatican City", "Monaco", "Rimini"]
            random_search_term = random.choice(search_terms)
            search_input.send_keys(random_search_term)
        except Exception as e:
            pass  # Gérer l'exception, par exemple, en ne faisant rien

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
from itertools import combinations
import random
ua = UserAgent()
user_agent = ua.random

villes = [  "WAW", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS","PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL","BER", "STO", "HEL", "REK", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')
random_sleep = random.uniform(2, 5)
random_week_sleep = random.uniform(30,45)
all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date_final = datetime(2024, 1, 22)
city_pairs = list(combinations(villes, 2))
# Boucle sur les semaines
while start_date <= end_date_final:
    for pair in city_pairs:
        ville1, ville2 = pair

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            time.sleep(random_sleep)
                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(random_week_sleep)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(random_sleep)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')
        time.sleep(random_sleep)
        action_aleatoire(driver)

        for voyage in voyages:
            time.sleep(5)
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            action_aleatoire(driver)
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
            data_entry = {"Date_Départ":start_date.strftime("%Y-%m-%d"),"Date_arrivée":end_date.strftime("%Y-%m-%d"),  "VILLE_DEPART": ville1,"VILLE_ARRIVEE": ville2,"Horaires": horaires,"Trajet": trajet,"Type de trajet": type_trajet,"Temps de trajet": temps_trajet,"Prix": prix,"Compagnie de vol": Compagnie}
            time.sleep(random_sleep)
            all_data.append(data_entry)
            SauvCSV = pd.DataFrame( all_data)
            SauvCSV.to_csv('SauvK_b.csv',mode='a',index=True,encoding='utf-8')
            print("done")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)
df = pd.DataFrame(all_data)
                          # Specify the CSV file path
csv_file = "data_kayak.csv"

# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False)
print('Fin du scraping')
# Out:
# Début scrape des villes WAW et PRG pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes WAW et BUD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 07:45 – 09:05
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 188 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 08:10 – 09:30
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 99 €
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 12:30 – 21:30
# Trajet: WMIAéroport de Mazovie Varsovie-Modlin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 9h 00min
# Prix: 89 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 19:40
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 151 €
# Compagnie de vol: LOT, Wizz Air
# ========================================
# done
# Horaires: 07:45 – 09:05
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 151 €
# Compagnie de vol: LOT, Wizz Air
# ========================================
# done
# Horaires: 15:50 – 17:10
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 151 €
# Compagnie de vol: LOT, Wizz Air
# ========================================
# done
# Horaires: 10:50 – 12:10
# Trajet: WAWAéroport de Varsovie-Chopin-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix:
€
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 18:55 – 00:05+1
# Trajet: WAWAéroport de Varsovie-Chopin-BEGNikola Tesla
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 170 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 19:25 – 23:30
# Trajet: WAWAéroport de Varsovie-Chopin-BEGNikola Tesla
# Type de trajet: 1 escale
# Temps de trajet: 4h 05min
# Prix: 181 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Début scrape des villes WAW et ZAG pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 10:25 – 12:05
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 268 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 10:25 – 12:05
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 170 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 06:00 – 12:10
# Trajet: WMIAéroport de Mazovie Varsovie-Modlin-ZAGFranjo Tuđman
# Type de trajet:
# Temps de trajet: 6h 10min
# Prix: 139 €
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 168 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 09:15 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 175 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 259 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 237 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 17:20 – 20:25
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 05min
# Prix: 259 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 10:25 – 12:05
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 281 €
# Compagnie de vol: LOT, Croatia Airlines
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 236 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 07:20 – 11:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 40min
# Prix: 259 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 244 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 06:50 – 11:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 4h 10min
# Prix: 259 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 17:20 – 20:25
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 05min
# Prix: 342 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 10:10 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 3h 50min
# Prix: 244 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 09:15 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 266 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 09:15 – 14:00
# Trajet: WAWAéroport de Varsovie-Chopin-ZAGFranjo Tuđman
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 244 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Début scrape des villes WAW et TIA pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 44 €
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 32 €
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 10:35 – 12:40
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 05min
# Prix: 95 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 10:35 – 12:40
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 05min
# Prix: 96 €
# Compagnie de vol: LOT, Ryanair
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 113 €
# Compagnie de vol: Wizz Air, LOT
# ========================================
# done
# Horaires: 18:05 – 00:15+1
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 6h 10min
# Prix: 60 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:15 – 15:40
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 9h 25min
# Prix: 55 €
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 12:30 – 19:10
# Trajet: WMIAéroport de Mazovie Varsovie-Modlin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 6h 40min
# Prix: 69 €
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 18:05 – 23:20
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 5h 15min
# Prix: 83 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 89 €
# Compagnie de vol: Wizz Air, Wizz Air Malta
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 61 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 55 €
# Compagnie de vol: Wizz Air, Wizz Air UK
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 82 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 11:55 – 14:10
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 101 €
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 18:05 – 00:15+1
# Trajet: WAWAéroport de Varsovie-Chopin-TIAAéroport Intl de Tirana
# Type de traj
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 9h 45min
# Prix: 179 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 06:45 – 14:05
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 6h 20min
# Prix: 196 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 06:00 – 13:10
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 6h 10min
# Prix: 259 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 13:15 – 22:20
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 211 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 12:55 – 22:20
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 8h 25min
# Prix: 307 €
# Compagnie de vol: airBaltic, LOT
# ========================================
# done
# Horaires: 13:45 – 00:30+1
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 9h 45min
# Prix: 179 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 11:05 – 22:20
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 10h 15min
# Prix: 265 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 06:45 – 14:05
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 6h 20min
# Prix: 312 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 06:00 – 13:10
# Trajet: BEGNikola Tesla-RIXAéroport Intl de Riga
# Type de trajet: 1 escale
# Temps de trajet: 6h 10min
# Prix: 334 €
# Compagnie de vol: KLM
# ========================================
# done
# Début scrape des villes BEG et VNO pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:00 – 14:05+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 23h 05min
# Prix: 138 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 07:00 – 12:45
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 165 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 14:00 – 14:05+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 23h 05min
# Prix: 131 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 17:15 – 01:00+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 6h 45min
# Prix: 220 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 06:45 – 14:25
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 6h 40min
# Prix: 159 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 07:00 – 12:45
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 229 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 07:00 – 12:45
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 225 €
# Compagnie de vol: Austrian Airlines, airBaltic
# ========================================
# done
# Horaires: 18:00 – 01:40+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet:
# Temps de trajet: 6h 40min
# Prix: 203 €
# Compagnie de vol: Air Serbia, Wizz Air
# ========================================
# done
# Horaires: 17:15 – 01:00+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 6h 45min
# Prix: 220 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:00 – 01:00+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 10h 00min
# Prix: 220 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 17:15 – 01:00+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 6h 45min
# Prix: 220 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 13:45 – 23:45
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 9h 00min
# Prix: 159 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 06:45 – 14:25
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 6h 40min
# Prix: 223 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 18:00 – 01:40+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet:
# Temps de trajet: 6h 40min
# Prix: 214 €
# Compagnie de vol: Air Serbia, Wizz Air
# ========================================
# done
# Horaires: 18:00 – 01:40+1
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet:
# Temps de trajet: 6h 40min
# Prix: 165 €
# Compagnie de vol: Air Serbia, Wizz Air
# ========================================
# done
# Horaires: 07:00 – 12:45
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 4h 45min
# Prix: 312 €
# Compagnie de vol: Austrian Airlines, LOT
# ========================================
# done
# Horaires: 13:15 – 22:00
# Trajet: BEGNikola Tesla-VNOAéroport de Vilnius
# Type de trajet: 1 escale
# Temps de trajet: 7h 45min
# Prix: 191 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Début scrape des villes BEG et KIV pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et MSQ pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et TBS pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et PAR pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et MAD pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et LON pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et LIS pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et BRU pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et CPH pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes BEG et OSL pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2840\3142024759.py in <module>
#      42                 driver.quit()
#      43                 continue
# ---> 44         time.sleep(random_week_sleep)
#      45
#      46         # Fonction auxiliaire pour récupérer des données
#
# KeyboardInterrupt:
