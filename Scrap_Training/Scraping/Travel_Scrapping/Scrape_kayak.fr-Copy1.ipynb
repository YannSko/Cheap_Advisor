# %%
 ###https://www.kayak.fr/flights/CDG-MAD/2023-11-22/2023-11-29?sort=bestflight_a

# %% [markdown]
# # kayak.fr

# %% [markdown]
# ## Import

# %%
# Scrappe and Clean
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta


import pandas as pd 
import numpy as np 


from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# ## Scrappe

# %%
ua = UserAgent()
user_agent = ua.random

villes = ["PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD","BER",  "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')

all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date = datetime(2023, 11, 28)

# Boucle sur les semaines
while start_date <= end_date_final:
    for i in range(0, len(villes), 2):
        ville1 = villes[i]
        ville2 = villes[i + 1]

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')

                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            time.sleep(10)
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(2)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(2)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')


        for voyage in voyages:
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)

print('Fin du scraping')
# Out:
# Début scrape des villes PAR et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 31 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 44 €
# Compagnie de vol: Ryanair, Vueling
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes MAD et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 62 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 22:00 – 23:35
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 57 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 69 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 68 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 74 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes LIS et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 07:45 – 16:10
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 7h 25min
# Prix: 133 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 166 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 17:25 – 21:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 170 €
# Compagnie de vol: Vueling
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 181 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 19:30 – 23:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 192 €
# Compagnie de vol: Transavia, Vueling
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 201 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 15:25 – 19:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 218 €
# Compagnie de vol: KLM
# ========================================
# Début scrape des villes BRU et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol: Aer Lingus, Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 90 €
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 18:55 – 19:40
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 150 €
# Compagnie de vol: Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes CPH et OSL pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3.2\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 28
#      24 ville2 = villes[i + 1]
#      26 print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')
# ---> 28 driver = webdriver.Firefox(options=options)
#      29 try:
#      30     driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:60, in WebDriver.__init__(self, options, service, keep_alive)
#      57 options = options if options else Options()
#      59 self.service.path = DriverFinder.get_path(self.service, options)
# ---> 60 self.service.start()
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     ignore_proxy=options._ignore_local_proxy,
#      65     keep_alive=keep_alive,
#      66 )
#      67 super().__init__(command_executor=executor, options=options)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:103, in Service.start(self)
#     101 while True:
#     102     self.assert_process_still_running()
# --> 103     if self.is_connectable():
#     104         break
#     106     count += 1
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:120, in Service.is_connectable(self)
#     117 def is_connectable(self) -> bool:
#     118     """Establishes a socket connection to determine if the service running
#     119     on the port is accessible."""
# --> 120     return utils.is_connectable(self.port)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\utils.py:101, in is_connectable(port, host)
#      99 socket_ = None
#     100 try:
# --> 101     socket_ = socket.create_connection((host, port), 1)
#     102     result = True
#     103 except _is_connectable_exceptions:
#
# File ~\anaconda3.2\Lib\socket.py:843, in create_connection(address, timeout, source_address, all_errors)
#     841 except error as exc:
#     842     if not all_errors:
# --> 843         exceptions.clear()  # raise only the last error
#     844     exceptions.append(exc)
#     845     if sock is not None:
#
# KeyboardInterrupt:

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException

def action_aleatoire(driver):
    actions_possibles = ["scroll", "click_button", "fill_text"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "click_button":
        # Action aléatoire : Cliquez sur un élément aléatoire (par exemple, un bouton de tri)
        wait = WebDriverWait(driver, 10)
        elements = wait.until(EC.presence_of_all_elements_located((By.XPATH, ".//button[@class='Iqt3 Iqt3-mod-bold Button-No-Standard-Style Iqt3-mod-variant-outline Iqt3-mod-theme-none Iqt3-mod-shape-rounded-small Iqt3-mod-shape-mod-default Iqt3-mod-spacing-default Iqt3-mod-size-default']")))
        
        if elements:
            random_button = random.choice(elements)
            try:
                random_button.click()
            except ElementClickInterceptedException:
                pass  # Gérer l'exception, par exemple, en ne faisant rien

    elif action_choisie == "fill_text":
        # Action aléatoire : Remplissez un champ de texte (par exemple, une recherche)
        wait = WebDriverWait(driver, 10)
        try:
            search_input = wait.until(EC.visibility_of_element_located((By.XPATH, ".//input[@class='k_my-input']")))
            search_terms = ["Amsterdam", "Brussels", "Dublin", "Berlin", "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Reykjavik", "Moscow", "Warsaw", "Paris", "Rome", "Madrid", "London", "Lisbon", "Prague", "Budapest", "Vienna", "Athens", "Bucharest", "Sofia", "Belgrade", "Zagreb", "Tirana", "Skopje", "Podgorica", "Pristina", "Tallinn", "Riga", "Vilnius", "Chișinău", "Minsk", "Kyiv", "Tbilisi", "Yerevan", "Baku", "Ankara", "Ercan", "Valletta", "Vatican City", "Monaco", "Rimini"]
            random_search_term = random.choice(search_terms)
            search_input.send_keys(random_search_term)
        except Exception as e:
            pass  # Gérer l'exception, par exemple, en ne faisant rien

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
from itertools import combinations
import random
ua = UserAgent()
user_agent = ua.random

villes = [  "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI","PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL","BER", "STO", "HEL", "REK", "WAW", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO",]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')
random_sleep = random.uniform(2, 5)
random_week_sleep = random.uniform(30,45)
all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date_final = datetime(2024, 1, 22)
city_pairs = list(combinations(villes, 2))
# Boucle sur les semaines
while start_date <= end_date_final:
    for pair in city_pairs:
        ville1, ville2 = pair

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            time.sleep(random_sleep)
                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(random_week_sleep)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(random_sleep)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')
        time.sleep(random_sleep)
        action_aleatoire(driver)

        for voyage in voyages:
            time.sleep(5)
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            action_aleatoire(driver)
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
            data_entry = {"Date_Départ":start_date.strftime("%Y-%m-%d"),"Date_arrivée":end_date.strftime("%Y-%m-%d"),  "VILLE_DEPART": ville1,"VILLE_ARRIVEE": ville2,"Horaires": horaires,"Trajet": trajet,"Type de trajet": type_trajet,"Temps de trajet": temps_trajet,"Prix": prix,"Compagnie de vol": Compagnie}
            time.sleep(random_sleep)
            all_data.append(data_entry)
            SauvCSV = pd.DataFrame( all_data)
            SauvCSV.to_csv('SauvK_b.csv',mode='a',index=True,encoding='utf-8')
            print("done")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)
df = pd.DataFrame(all_data)
                          # Specify the CSV file path
csv_file = "data_kayak.csv"

# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False)
print('Fin du scraping')
# Out:
# Début scrape des villes KIV et MSQ pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et TBS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 230 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 215 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 362 €
# Compagnie de vol: FLYONE, Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 11h 40min
# Prix: 215 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 215 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 325 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 356 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 14:45 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 11h 40min
# Prix: 215 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 09:40 – 16:45
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 5h 05min
# Prix: 454 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 18:20 – 04:25+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 406 €
# Compagnie de vol: LOT, Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 05:15+1
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: 1 escale
# Temps de trajet: 5h 45min
# Prix: 454 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:50 – 16:45
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet:
# Temps de trajet: 5h 55min
# Prix: 392 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 315 €
# Compagnie de vol: FLYONE, Pegasus Airlines
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 356 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 315 €
# Compagnie de vol: FLYONE, FLYONE Armenia
# ========================================
# done
# Horaires: 01:00 – 05:20
# Trajet: KIVChisinau-TBSAéroport de Tbilissi
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 327 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Début scrape des villes KIV et EVN pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 267 €
# Compagnie de vol: FLYONE Armenia
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 262 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 262 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 01:30 – 06:10
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 262 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 01:30 – 06:10
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 262 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 265 €
# Compagnie de vol: FLYONE Armenia
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 265 €
# Compagnie de vol: FLYONE Armenia
# ========================================
# done
# Horaires: 01:30 – 06:10
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 265 €
# Compagnie de vol: FLYONE Armenia
# ========================================
# done
# Horaires: 01:30 – 06:10
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 265 €
# Compagnie de vol: FLYONE Armenia
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 268 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 268 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 268 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 268 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 269 €
# Compagnie de vol: FLYONE Armenia, FLYONE
# ========================================
# done
# Horaires: 14:00 – 18:30
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 269 €
# Compagnie de vol: FLYONE Armenia, FLYONE
# ========================================
# done
# Horaires: 01:30 – 06:10
# Trajet: KIVChisinau-EVNAéroport international Zvartnots
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 268 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Début scrape des villes KIV et BAK pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 243 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 240 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 21:30 – 06:10+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 6h 40min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 10h 50min
# Prix: 241 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 241 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 21:30 – 06:10+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 6h 40min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 01:50+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 8h 35min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 18:20 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 342 €
# Compagnie de vol: LOT, Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 06:10+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 6h 40min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 10h 50min
# Prix: 240 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 09:40 – 20:55
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 9h 15min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 18:20 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 342 €
# Compagnie de vol: LOT, Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 01:50+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 8h 35min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 20:55
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 9h 15min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 01:50+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 8h 35min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 03:35+1
# Trajet: KIVChisinau-GYDAéroport Intl Heydar Aliyev de Bakou
# Type de trajet: 1 escale
# Temps de trajet: 10h 50min
# Prix: 342 €
# Compagnie de vol: LOT, Turkish Airlines
# ========================================
# done
# Début scrape des villes KIV et ANK pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 02:40 – 12:20
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 2 escales
# Temps de trajet: 8h 40min
# Prix: 305 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 08:50 – 14:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 4h 20min
# Prix: 236 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 02:40 – 22:40
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 19h 00min
# Prix: 212 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:50 – 15:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 5h 20min
# Prix: 236 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 02:40 – 10:55
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 7h 15min
# Prix: 224 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 21:30 – 03:10+1
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 1 escale
# Temps de trajet: 4h 40min
# Prix: 365 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:50 – 14:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 4h 20min
# Prix: 239 €
# Compagnie de vol: FLYONE, Turkish Airlines
# ========================================
# done
# Horaires: 08:50 – 14:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 4h 20min
# Prix: 254 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:50 – 14:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 4h 20min
# Prix: 258 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:40 – 15:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 1 escale
# Temps de trajet: 4h 30min
# Prix: 397 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:50 – 16:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 6h 20min
# Prix: 236 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 21:30 – 03:10+1
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 1 escale
# Temps de trajet: 4h 40min
# Prix: 365 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 20:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 3h 55min
# Prix: 319 €
# Compagnie de vol: Turkish Airlines, Eagle Air Ltd.
# ========================================
# done
# Horaires: 08:50 – 14:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 4h 20min
# Prix: 239 €
# Compagnie de vol: FLYONE, Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 03:10+1
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 1 escale
# Temps de trajet: 4h 40min
# Prix: 365 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 22:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet: 1 escale
# Temps de trajet: 5h 55min
# Prix: 365 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:50 – 15:10
# Trajet: KIVChisinau-ESBAnkara Aéroport Intl Esenboga
# Type de trajet:
# Temps de trajet: 5h 20min
# Prix: 239 €
# Compagnie de vol: FLYONE, Turkish Airlines
# ========================================
# done
# Début scrape des villes KIV et ECN pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 335 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 326 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 02:40 – 13:50
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet:
# Temps de trajet: 11h 10min
# Prix: 263 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 326 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 14:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 20:30
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 15min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 338 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 14:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 14:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 362 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 20:30
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 15min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 15:15 – 20:30
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 5h 15min
# Prix: 362 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 16:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 7h 00min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 16:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 7h 00min
# Prix: 348 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 09:40 – 16:40
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 7h 00min
# Prix: 362 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 08:35+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 11h 05min
# Prix: 326 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 21:30 – 02:25+1
# Trajet: KIVChisinau-ECNAéroport Intl Ercan
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 326 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Début scrape des villes KIV et MLA pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et VAT pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et MCM pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et RMI pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes KIV et PAR pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:45 – 10:00+1
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 20h 15min
# Prix: 211 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 251 €
# Compagnie de vol: LOT, HiSky
# ========================================
# done
# Horaires: 07:50 – 22:30
# Trajet: KIVChisinau-BVAAéroport de Beauvais-Tillé
# Type de trajet: direct
# Temps de trajet: 15h 40min
# Prix: 204 €
# Compagnie de vol: HiSky, Ryanair
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 214 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:45
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 25min
# Prix: 251 €
# Compagnie de vol: LOT, HiSky
# ========================================
# done
# Horaires: 18:20 – 22:45
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 25min
# Prix: 214 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 17:20 – 22:30
# Trajet: KIVChisinau-ORYAéroport de Paris-Orly
# Type de trajet: direct
# Temps de trajet: 6h 10min
# Prix: 229 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 05:25 – 11:00
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 6h 35min
# Prix: 262 €
# Compagnie de vol: TAROM, HiSky
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 315 €
# Compagnie de vol: LOT, A.P.G.
# ========================================
# done
# Horaires: 18:20 – 22:45
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 25min
# Prix: 315 €
# Compagnie de vol: LOT, A.P.G.
# ========================================
# done
# Horaires: 10:00 – 15:30
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 6h 30min
# Prix: 284 €
# Compagnie de vol: TAROM, HiSky
# ========================================
# done
# Horaires: 05:25 – 11:00
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 6h 35min
# Prix: 279 €
# Compagnie de vol: TAROM
# ========================================
# done
# Horaires: 15:15 – 22:20
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 8h 05min
# Prix: 293 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 214 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:45
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 5h 25min
# Prix: 214 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:45 – 22:45
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 9h 00min
# Prix: 214 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 15:55 – 19:25
# Trajet: KIVChisinau-CDGAéroport Charles-de-Gaulle
# Type de trajet: 1 escale
# Temps de trajet: 4h 30min
# Prix: 610 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Début scrape des villes KIV et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 15:15 – 21:55
# Trajet: KIVChisinau-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 7h 40min
# Prix: 297 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes KIV et MAD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:40 – 16:20
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 40min
# Prix: 278 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 247 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 23:50
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 14h 50min
# Prix: 245 €
# Compagnie de vol: FLYONE, Ryanair
# ========================================
# done
# Horaires: 09:40 – 16:20
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 40min
# Prix: 271 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 265 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 23:50
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 11h 30min
# Prix: 247 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:40 – 16:20
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 40min
# Prix: 271 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 05:25 – 11:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 00min
# Prix: 296 €
# Compagnie de vol: TAROM
# ========================================
# done
# Horaires: 05:25 – 11:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 00min
# Prix: 311 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 294 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 264 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 317 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 266 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 290 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 249 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 19:25
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 7h 05min
# Prix: 261 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:40 – 16:20
# Trajet: KIVChisinau-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 40min
# Prix: 330 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Début scrape des villes KIV et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 12:20 – 13:30
# Trajet: KIVChisinau-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 09:50 – 11:30
# Trajet: KIVChisinau-LTNAéroport de Londres Luton
# Type de trajet: direct
# Temps de trajet: 3h 40min
# Prix: 185 €
# Compagnie de vol: FLYONE
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes KIV et LIS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 15:55 – 22:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 35min
# Prix: 694 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 10:00 – 18:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 30min
# Prix: 326 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 09:05+1
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 21h 45min
# Prix: 265 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:50 – 18:20
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 30min
# Prix: 338 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 21:25
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 11h 05min
# Prix: 339 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:50 – 18:20
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 30min
# Prix: 305 €
# Compagnie de vol: FLYONE, Ryanair
# ========================================
# done
# Horaires: 09:50 – 17:55
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 315 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 14:45 – 22:50
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 414 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 21:25
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 11h 05min
# Prix: 349 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 15:55 – 22:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 35min
# Prix: 641 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 15:55 – 22:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 35min
# Prix: 801 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 15:55 – 22:50
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 55min
# Prix: 648 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 10:00 – 21:15
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 13h 15min
# Prix: 378 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 15:55 – 22:50
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 55min
# Prix: 808 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 15:55 – 22:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 35min
# Prix: 676 €
# Compagnie de vol: Austrian Airlines, Lufthansa
# ========================================
# done
# Horaires: 15:55 – 22:30
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 35min
# Prix: 692 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 15:55 – 22:50
# Trajet: KIVChisinau-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 2 escales
# Temps de trajet: 8h 55min
# Prix: 699 €
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Début scrape des villes KIV et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 316 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 273 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 272 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 275 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 301 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 301 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:45 – 18:55
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 301 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 301 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 15:15 – 21:10
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 6h 55min
# Prix: 286 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 314 €
# Compagnie de vol: FLYONE, TAROM
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 273 €
# Compagnie de vol: FLYONE, LOT
# ========================================
# done
# Horaires: 15:15 – 21:10
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 6h 55min
# Prix: 346 €
# Compagnie de vol: Turkish Airlines, LOT
# ========================================
# done
# Horaires: 15:15 – 21:10
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 6h 55min
# Prix: 346 €
# Compagnie de vol: Turkish Airlines, LOT
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 301 €
# Compagnie de vol: FLYONE, easyJet
# ========================================
# done
# Horaires: 15:55 – 19:15
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 4h 20min
# Prix: 516 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 05:25 – 10:40
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 6h 15min
# Prix: 343 €
# Compagnie de vol: TAROM, LOT
# ========================================
# done
# Horaires: 12:30 – 14:50
# Trajet: KIVChisinau-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 520 €
# Compagnie de vol: FLYONE, Austrian Airlines
# ========================================
# done
# Début scrape des villes KIV et BRU pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:45 – 18:45
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 329 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 19:45 – 18:40+1
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 23h 55min
# Prix: 255 €
# Compagnie de vol: TAROM
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 329 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:45 – 18:45
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 329 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 329 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 14:45 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 8h 45min
# Prix: 334 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 334 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 15:55 – 19:05
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 4h 10min
# Prix: 539 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 15:55 – 20:00
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 05min
# Prix: 510 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 14:45 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 8h 45min
# Prix: 334 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires: 09:40 – 17:05
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 8h 25min
# Prix: 287 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 14:45 – 18:45
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 368 €
# Compagnie de vol: LOT, KLM
# ========================================
# done
# Horaires: 18:20 – 22:30
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 5h 10min
# Prix: 368 €
# Compagnie de vol: LOT, KLM
# ========================================
# done
# Horaires: 09:40 – 17:05
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 8h 25min
# Prix: 325 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 10:00 – 18:40
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 9h 40min
# Prix: 552 €
# Compagnie de vol: TAROM, LOT
# ========================================
# done
# Horaires: 10:00 – 18:40
# Trajet: KIVChisinau-BRUAéroport de Bruxelles-National
# Type de trajet: 1 escale
# Temps de trajet: 9h 40min
# Prix: 293 €
# Compagnie de vol: TAROM
# ========================================
# done
# Début scrape des villes KIV et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:40 – 15:50
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: 1 escale
# Temps de trajet: 8h 10min
# Prix: 385 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 12:20 – 16:30
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 6h 10min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 19:35
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 11h 35min
# Prix: 205 €
# Compagnie de vol: FLYONE, Ryanair
# ========================================
# done
# Horaires: 12:20 – 16:30
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 6h 10min
# Prix: 221 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 16:30
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 6h 10min
# Prix: 229 €
# Compagnie de vol: Eagle Air Ltd., Ryanair
# ========================================
# done
# Horaires: 12:20 – 19:25
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 9h 05min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 19:35
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 11h 35min
# Prix: 207 €
# Compagnie de vol: FLYONE, Ryanair
# ========================================
# done
# Horaires: 09:40 – 15:50
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: 1 escale
# Temps de trajet: 8h 10min
# Prix: 381 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 12:20 – 20:15
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 9h 55min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:30 – 17:20
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 6h 50min
# Prix: 293 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:30 – 17:20
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 6h 50min
# Prix: 291 €
# Compagnie de vol: FLYONE, Ryanair
# ========================================
# done
# Horaires: 12:20 – 16:30
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 6h 10min
# Prix: 227 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 19:25
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 9h 05min
# Prix: 221 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 21:20
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 11h 00min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 21:45
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 11h 25min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 20:15
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet:
# Temps de trajet: 9h 55min
# Prix: 221 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 12:20 – 21:25
# Trajet: KIVChisinau-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 11h 05min
# Prix: 219 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Début scrape des villes KIV et CPH pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 446 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 402 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 446 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 21:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 12h 10min
# Prix: 467 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 21:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 12h 10min
# Prix: 422 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 537 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 519 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 21:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 12h 10min
# Prix: 467 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 537 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 21:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 12h 10min
# Prix: 558 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# Type de trajet: 2 escales
# Temps de trajet: 9h 10min
# Prix: 516 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 05:25 – 16:35
# Trajet: KIVChisinau-CPHAéroport de Copenhague Kastrup
# ...
# Type de trajet: 1 escale
# Temps de trajet: 5h 35min
# Prix: 274 €
# Compagnie de vol: AnadoluJet, Turkish Airlines
# ========================================
# done
# Horaires: 12:55 – 16:40
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 5h 45min
# Prix: 187 €
# Compagnie de vol: Pegasus Airlines, AnadoluJet
# ========================================
# done
# Horaires: 08:20 – 11:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 5h 35min
# Prix: 331 €
# Compagnie de vol: AnadoluJet, Turkish Airlines
# ========================================
# done
# Horaires: 05:40 – 11:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet:
# Temps de trajet: 7h 45min
# Prix: 191 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 07:05 – 11:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 6h 20min
# Prix: 195 €
# Compagnie de vol: Pegasus Airlines, AnadoluJet
# ========================================
# done
# Horaires: 08:20 – 11:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 5h 35min
# Prix: 331 €
# Compagnie de vol: AnadoluJet, Turkish Airlines
# ========================================
# done
# Horaires: 10:00 – 16:40
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 8h 40min
# Prix: 208 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 07:05 – 11:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-FCOAéroport Léonard-de-Vinci de Rome Fiumicino
# Type de trajet: 1 escale
# Temps de trajet: 6h 20min
# Prix: 197 €
# Compagnie de vol: Pegasus Airlines, Ryanair
# ========================================
# done
# Début scrape des villes ANK et MAD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 8h 30min
# Prix: 369 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 21:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 257 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 19:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 11h 25min
# Prix: 231 €
# Compagnie de vol: Pegasus Airlines, Ryanair
# ========================================
# done
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 8h 30min
# Prix: 367 €
# Compagnie de vol: Pegasus Airlines, Turkish Airlines
# ========================================
# done
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 8h 30min
# Prix: 367 €
# Compagnie de vol: Pegasus Airlines, Turkish Airlines
# ========================================
# done
# Horaires: 05:40 – 11:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 55min
# Prix: 375 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 21:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 305 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 8h 30min
# Prix: 292 €
# Compagnie de vol: Pegasus Airlines, Ryanair
# ========================================
# done
# Horaires: 05:40 – 11:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 55min
# Prix: 436 €
# Compagnie de vol: Pegasus Airlines, Turkish Airlines
# ========================================
# done
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 8h 30min
# Prix: 353 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 10:00 – 19:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 11h 25min
# Prix: 279 €
# Compagnie de vol: Pegasus Airlines, Ryanair
# ========================================
# done
# Horaires: 05:40 – 11:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 7h 55min
# Prix: 372 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 21:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 327 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 05:40 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 9h 55min
# Prix: 351 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 21:25
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 302 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 07:05 – 13:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-MADAéroport de Madrid-Barajas
# Type de trajet: 1 escale
# Temps de trajet: 8h 30min
# Prix: 351 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Début scrape des villes ANK et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 156 €
# Compagnie de vol: Turkish Airlines, Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 146 €
# Compagnie de vol: Turkish Airlines, Pegasus Airlines
# ========================================
# done
# Horaires: 17:35 – 22:10
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 7h 35min
# Prix: 153 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 168 €
# Compagnie de vol: Turkish Airlines, AnadoluJet
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 149 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 152 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:20 – 11:45
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 188 €
# Compagnie de vol: AnadoluJet, Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 177 €
# Compagnie de vol: Turkish Airlines, Pegasus Airlines
# ========================================
# done
# Horaires: 17:35 – 22:10
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 7h 35min
# Prix: 184 €
# Compagnie de vol: Pegasus Airlines, AnadoluJet
# ========================================
# done
# Horaires: 05:40 – 09:30
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 6h 50min
# Prix: 189 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 08:20 – 11:45
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 218 €
# Compagnie de vol: AnadoluJet
# ========================================
# done
# Horaires: 07:05 – 11:50
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 7h 45min
# Prix: 179 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 12:55 – 22:10
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: 1 escale
# Temps de trajet: 12h 15min
# Prix: 153 €
# Compagnie de vol: Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 187 €
# Compagnie de vol: Turkish Airlines, Wizz Air UK
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 199 €
# Compagnie de vol: Turkish Airlines, Pegasus Airlines
# ========================================
# done
# Horaires: 13:20 – 14:55
# Trajet: ESBAnkara Aéroport Intl Esenboga-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 4h 35min
# Prix: 174 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Début scrape des villes ANK et LIS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 10:00 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 8h 20min
# Prix: 504 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 10:00 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 8h 20min
# Prix: 487 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 22:05 – 19:30+1
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 24h 25min
# Prix: 266 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 8h 20min
# Prix: 505 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:55 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 9h 25min
# Prix: 487 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 07:05 – 16:30
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 12h 25min
# Prix: 273 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:55 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 9h 25min
# Prix: 505 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:40 – 15:05
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 9h 25min
# Prix: 440 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 8h 20min
# Prix: 505 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:20 – 16:30
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 11h 10min
# Prix: 292 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 05:40 – 16:30
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 13h 50min
# Prix: 269 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 04:20 – 10:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 9h 15min
# Prix: 547 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 04:20 – 10:35
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 9h 15min
# Prix: 563 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 06:35 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 11h 45min
# Prix: 487 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 08:55 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 9h 25min
# Prix: 505 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Horaires: 10:00 – 18:10
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 11h 10min
# Prix: 302 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:35 – 15:20
# Trajet: ESBAnkara Aéroport Intl Esenboga-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: 1 escale
# Temps de trajet: 11h 45min
# Prix: 505 €
# Compagnie de vol: Turkish Airlines
# ========================================
# done
# Début scrape des villes ANK et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et BRU pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et CPH pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et OSL pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et BER pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et STO pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et HEL pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et REK pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et WAW pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et PRG pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et BUD pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et VIE pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et ATH pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ANK et BUH pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11996\98703790.py in <module>
#      42                 driver.quit()
#      43                 continue
# ---> 44         time.sleep(random_week_sleep)
#      45
#      46         # Fonction auxiliaire pour récupérer des données
#
# KeyboardInterrupt:
