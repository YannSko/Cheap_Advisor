# %% [markdown]
# # momondo.Fr

# %%
###https://www.momondo.fr/flight-search/PAR-FRA/2023-11-22/2023-11-28?sort=price_a

# %%
# Scrappe and Clean
# !pip install selenium
# !pip install pandas
# !pip install urllib3
# !pip install requests
# !pip install fake-useragent
# !pip install numpy
# Out:
# Requirement already satisfied: selenium in c:\users\yskon\anaconda3.2\lib\site-packages (4.14.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\yskon\anaconda3.2\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\yskon\anaconda3.2\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\yskon\anaconda3.2\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\yskon\anaconda3.2\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sniffio in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\yskon\anaconda3.2\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\yskon\anaconda3.2\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\yskon\anaconda3.2\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\yskon\anaconda3.2\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\yskon\anaconda3.2\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# ^C
# ^C
# ^C
# ^C
# Requirement already satisfied: pandas in c:\users\yskon\anaconda3.2\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yskon\anaconda3.2\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yskon\anaconda3.2\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\yskon\anaconda3.2\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\yskon\anaconda3.2\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\yskon\anaconda3.2\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: urllib3 in c:\users\yskon\anaconda3.2\lib\site-packages (1.26.16)
# Requirement already satisfied: fake-useragent in c:\users\yskon\anaconda3.2\lib\site-packages (1.3.0)
# Requirement already satisfied: requests in c:\users\yskon\anaconda3.2\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yskon\anaconda3.2\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yskon\anaconda3.2\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yskon\anaconda3.2\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yskon\anaconda3.2\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: numpy in c:\users\yskon\anaconda3.2\lib\site-packages (1.24.3)

# %% [markdown]
# ## Import

# %%
# Scrappe and Clean
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta


import pandas as pd 
import numpy as np 


from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# # Scrap

# %%
ua = UserAgent()
user_agent = ua.random

villes = ["BER", "PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')

all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date_final = datetime(2024, 1, 22)

# Boucle sur les semaines
while start_date <= end_date_final:
    for i in range(0, len(villes), 2):
        ville1 = villes[i]
        ville2 = villes[i + 1]

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        
        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            time.sleep(10)
            try:
                driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(2)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(2)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')


        for voyage in voyages:
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
        # Imprimer les résultats pour chaque voyage
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Type de voyage:", type_voyage)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)

print('Fin du scraping')
# Out:
# Début scrape des villes BER et PAR pour la semaine du 2023-11-22 au 2023-11-28
# KeyboardInterrupt

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException

def action_aleatoire(driver):
    actions_possibles = ["scroll", "click_button", "fill_text"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "click_button":
        # Action aléatoire : Cliquez sur un élément aléatoire (par exemple, un bouton de tri)
        wait = WebDriverWait(driver, 10)
        elements = wait.until(EC.presence_of_all_elements_located((By.XPATH, ".//button[@class='Iqt3 Iqt3-mod-bold Button-No-Standard-Style Iqt3-mod-variant-outline Iqt3-mod-theme-none Iqt3-mod-shape-rounded-small Iqt3-mod-shape-mod-default Iqt3-mod-spacing-default Iqt3-mod-size-default']")))
        
        if elements:
            random_button = random.choice(elements)
            try:
                random_button.click()
            except ElementClickInterceptedException:
                pass  # Gérer l'exception, par exemple, en ne faisant rien

    elif action_choisie == "fill_text":
        # Action aléatoire : Remplissez un champ de texte (par exemple, une recherche)
        wait = WebDriverWait(driver, 10)
        try:
            search_input = wait.until(EC.visibility_of_element_located((By.XPATH, ".//input[@class='k_my-input']")))
            search_terms = ["Amsterdam", "Brussels", "Dublin", "Berlin", "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Reykjavik", "Moscow", "Warsaw", "Paris", "Rome", "Madrid", "London", "Lisbon", "Prague", "Budapest", "Vienna", "Athens", "Bucharest", "Sofia", "Belgrade", "Zagreb", "Tirana", "Skopje", "Podgorica", "Pristina", "Tallinn", "Riga", "Vilnius", "Chișinău", "Minsk", "Kyiv", "Tbilisi", "Yerevan", "Baku", "Ankara", "Ercan", "Valletta", "Vatican City", "Monaco", "Rimini"]
            random_search_term = random.choice(search_terms)
            search_input.send_keys(random_search_term)
        except Exception as e:
            pass  # Gérer l'exception, par exemple, en ne faisant rien

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %% [markdown]
# ## Tache à réaliser : Clean Data

# %%
import time
import logging
from datetime import datetime, timedelta
from selenium import webdriver
from selenium.webdriver.common.by import By
from fake_useragent import UserAgent
import csv

ua = UserAgent()
user_agent = ua.random

villes = ["PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU","BER",  "DUB", "CPH", "OSL", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')

all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)


with open('scraping_results.csv', 'w', newline='') as csv_file:
    
    csv_writer = csv.writer(csv_file)
    
    csv_writer.writerow(["VILLE_DEPART", "VILLE_ARRIVEE", "Horaires", "Trajet", "Type de trajet", "Temps de trajet", "Prix", "Compagnie de vol"])


start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)


end_date_final = datetime(2024, 1, 22)


while start_date <= end_date_final:
    for i in range(0, len(villes), 2):
        ville1 = villes[i]
        ville2 = villes[i + 1]

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            time.sleep(10)
            try:
                driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(2)

        
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data

       
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')

        for voyage in voyages:
            
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')

            csv_writer.writerow([ville1, ville2, horaires, trajet, type_trajet, temps_trajet, prix, Compagnie])

            
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Type de voyage:", type_voyage)
            print("Compagnie de vol:", Compagnie)
            print("========================================")

       
        driver.quit()

    
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)

print('Fin du scraping')
# Out:
# Début scrape des villes PAR et ROM pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 43
#      39 ville2 = villes[i + 1]
#      41 print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')
# ---> 43 driver = webdriver.Firefox(options=options)
#      44 try:
#      45     driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:67, in WebDriver.__init__(self, options, service, keep_alive)
#      60 self.service.start()
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     ignore_proxy=options._ignore_local_proxy,
#      65     keep_alive=keep_alive,
#      66 )
# ---> 67 super().__init__(command_executor=executor, options=options)
#      69 self._is_remote = False
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\webdriver.py:205, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     203 self._authenticator_id = None
#     204 self.start_client()
# --> 205 self.start_session(capabilities)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\webdriver.py:289, in WebDriver.start_session(self, capabilities)
#     282 """Creates a new session with the desired capabilities.
#     283
#     284 :Args:
#     285  - capabilities - a capabilities dict to start the session with.
#     286 """
#     288 caps = _create_caps(capabilities)
# --> 289 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     290 self.session_id = response.get("sessionId")
#     291 self.caps = response.get("capabilities")
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\webdriver.py:342, in WebDriver.execute(self, driver_command, params)
#     339     elif "sessionId" not in params:
#     340         params["sessionId"] = self.session_id
# --> 342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
#     344     self.error_handler.check_response(response)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:297, in RemoteConnection.execute(self, command, params)
#     295 data = utils.dump_json(params)
#     296 url = f"{self._url}{path}"
# --> 297 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:318, in RemoteConnection._request(self, method, url, body)
#     315     body = None
#     317 if self.keep_alive:
# --> 318     response = self._conn.request(method, url, body=body, headers=headers)
#     319     statuscode = response.status
#     320 else:
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3.2\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3.2\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3.2\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3.2\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3.2\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from itertools import combinations
import random

ua = UserAgent()
user_agent = ua.random

villes = [  "LON", "LIS", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "AMS", "BRU", "DUB","BER", "CPH", "OSL", "STO", "HEL", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM","REK",  "WAW","PAR", "ROM", "MAD", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')
random_sleep = random.uniform(2, 5)
all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date_final = datetime(2023, 11, 28)
city_pairs = list(combinations(villes, 2))
# Boucle sur les semaines
while start_date <= end_date_final:
    for pair in city_pairs:
        ville1, ville2 = pair

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        
        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
            time.sleep(random_sleep)
           
            action_aleatoire(driver)
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
           
            try:
                driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        random_week_sleep = random.uniform(30,45)
        time.sleep(random_week_sleep)
        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(random_sleep)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')
        time.sleep(random_sleep)
        action_aleatoire(driver)
        for voyage in voyages:
            time.sleep(3)
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            action_aleatoire(driver)
        # Imprimer les résultats pour chaque voyage
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Type de voyage:", type_voyage)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
            time.sleep(random_sleep)
            data_entry = {"Date_Départ":start_date.strftime("%Y-%m-%d"),"Date_arrivée":end_date.strftime("%Y-%m-%d"),  "VILLE_DEPART": ville1,"VILLE_ARRIVEE": ville2,"Horaires": horaires,"Trajet": trajet,"Type de trajet": type_trajet,"Temps de trajet": temps_trajet,"Prix": prix,"Compagnie de vol": Compagnie}
            
            all_data.append(data_entry)
            print("done")
            SauvCSV = pd.DataFrame( all_data)
            SauvCSV.to_csv('Sauv_Z.csv',mode='a',index=True,encoding='utf-8')
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)
df = pd.DataFrame(all_data)
                          # Specify the CSV file path
csv_file = "data_momo.csv"

# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False)
print('Fin du scraping')
# Out:
# Début scrape des villes LON et LIS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 16:35 – 19:15
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 115 €
# Type de voyage: Discount
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# done
# Horaires: 15:35 – 18:20
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 45min
# Prix: 90 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 15:35 – 18:20
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 45min
# Prix: 90 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 11:25 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 7h 35min
# Prix: 91 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 11:25 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 7h 35min
# Prix: 92 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 11:25 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 7h 35min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 10:00 – 19:00
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 9h 00min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 10:00 – 19:00
# Trajet: LTNAéroport de Londres Luton-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 9h 00min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:35 – 16:30
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 6h 55min
# Prix: 93 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 08:50 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 10h 10min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 07:45 – 19:00
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 11h 15min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 16:00 – 21:30
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 5h 30min
# Prix: 94 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 12:00 – 21:15
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 9h 15min
# Prix: 94 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:35 – 16:30
# Trajet: STNAéroport de Londres Stansted-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 6h 55min
# Prix: 95 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 14:20 – 21:15
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 6h 55min
# Prix: 95 €
# Type de voyage: Standard, Économique
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 11:25 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet:
# Temps de trajet: 7h 35min
# Prix: 95 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Début scrape des villes LON et PRG pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 54 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 54 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 54 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 56 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air UK
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 56 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air UK
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 56 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air UK
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 56 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air UK
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 72 €
# Type de voyage: Standard
# Compagnie de vol: Wizz Air UK, easyJet
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 72 €
# Type de voyage: Standard
# Compagnie de vol: Wizz Air UK, easyJet
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 78 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 78 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 79 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 79 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 80 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LTNAéroport de Londres Luton-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 80 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air UK, Ryanair
# ========================================
# done
# Horaires: 06:00 – 08:55
# Trajet: LGWAéroport de Londres-Gatwick-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 80 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Début scrape des villes LON et BUD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 88 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 72 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 72 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 08:35 – 12:05
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 78 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 08:35 – 12:05
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 78 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 83 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 83 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 05:55 – 09:20
# Trajet: STNAéroport de Londres Stansted-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 85 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 05:55 – 09:20
# Trajet: STNAéroport de Londres Stansted-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 85 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 13:55 – 21:30
# Trajet: STNAéroport de Londres Stansted-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet:
# Temps de trajet: 6h 35min
# Prix: 85 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 13:55 – 21:30
# Trajet: STNAéroport de Londres Stansted-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet:
# Temps de trajet: 6h 35min
# Prix: 85 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 08:35 – 12:05
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 88 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 08:35 – 12:05
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 89 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 90 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 05:55 – 09:20
# Trajet: STNAéroport de Londres Stansted-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 91 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 19:55 – 23:25
# Trajet: LTNAéroport de Londres Luton-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 91 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Début scrape des villes LON et VIE pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 73 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 73 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 77 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 79 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Horaires: 08:20 – 11:30
# Trajet: STNAéroport de Londres Stansted-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 82 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 83 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 89 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air Malta
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 89 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:20 – 11:30
# Trajet: STNAéroport de Londres Stansted-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 89 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 08:20 – 11:30
# Trajet: STNAéroport de Londres Stansted-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 90 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 08:35 – 11:50
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 90 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 08:20 – 11:30
# Trajet: STNAéroport de Londres Stansted-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 92 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 19:20 – 22:35
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 93 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Horaires: 08:20 – 11:30
# Trajet: STNAéroport de Londres Stansted-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 95 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 19:20 – 22:35
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 99 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 19:20 – 22:35
# Trajet: LGWAéroport de Londres-Gatwick-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 100 €
# Type de voyage: Value
# Compagnie de vol: Wizz Air Malta, Ryanair
# ========================================
# done
# Début scrape des villes LON et ATH pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 123 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 100 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 100 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 100 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 100 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 101 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:45 – 09:40+1
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 12h 55min
# Prix: 105 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 106 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 108 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Sky Express
# ========================================
# done
# Horaires: 21:35 – 09:40+1
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 108 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 21:35 – 09:40+1
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 10h 05min
# Prix: 108 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 109 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Sky Express
# ========================================
# done
# Horaires: 09:35 – 17:35
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 6h 00min
# Prix: 109 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:35 – 17:35
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 6h 00min
# Prix: 109 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:20 – 23:55
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet: direct
# Temps de trajet: 3h 35min
# Prix: 109 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:35 – 17:35
# Trajet: STNAéroport de Londres Stansted-ATHAéroport d'Elefthérios-Venizélos
# Type de trajet:
# Temps de trajet: 6h 00min
# Prix: 110 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Sky Express
# ========================================
# done
# Début scrape des villes LON et BUH pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 97 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 62 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 75 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 77 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 78 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 78 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 14:00 – 19:20
# Trajet: LTNAéroport de Londres Luton-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 79 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air UK
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 79 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air Malta
# ========================================
# done
# Horaires: 14:00 – 19:20
# Trajet: LTNAéroport de Londres Luton-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 80 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:45 – 14:50
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 81 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 05:55 – 11:00
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 81 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 81 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 82 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 14:00 – 19:20
# Trajet: LTNAéroport de Londres Luton-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 20min
# Prix: 82 €
# Type de voyage: Value
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 82 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Horaires: 15:30 – 20:35
# Trajet: STNAéroport de Londres Stansted-OTPOtopeni Intl
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 82 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air UK
# ========================================
# done
# Début scrape des villes LON et SOF pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:45 – 14:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 35 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 09:45 – 14:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 34 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 16:45 – 21:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 37 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 06:20 – 11:20
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 38 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 20:50 – 01:55+1
# Trajet: LTNAéroport de Londres Luton-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 38 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 08:45 – 13:55
# Trajet: LTNAéroport de Londres Luton-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 39 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 09:45 – 14:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 45 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 09:45 – 14:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 47 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 16:45 – 21:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 48 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 16:45 – 21:45
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 49 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 06:20 – 11:20
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 50 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 20:50 – 01:55+1
# Trajet: LTNAéroport de Londres Luton-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 50 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 06:20 – 11:20
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 51 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 08:45 – 13:55
# Trajet: LTNAéroport de Londres Luton-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 51 €
# Type de voyage: Économique
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 18:45 – 10:10+1
# Trajet: STNAéroport de Londres Stansted-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 13h 25min
# Prix: 51 €
# Type de voyage: Value, Économique
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 20:50 – 01:55+1
# Trajet: LTNAéroport de Londres Luton-SOFAéroport Intl de Sofia (Vrajdebna)
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 53 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Début scrape des villes LON et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 98 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:25 – 20:35
# Trajet: LTNAéroport de Londres Luton-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 74 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 20:00 – 22:10
# Trajet: LTNAéroport de Londres Luton-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 75 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 75 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 76 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 15:15 – 17:25
# Trajet: LTNAéroport de Londres Luton-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 77 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 77 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 77 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 15:15 – 17:25
# Trajet: LTNAéroport de Londres Luton-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 78 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 18:20 – 20:40
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 78 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 19:30 – 21:40
# Trajet: STNAéroport de Londres Stansted-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 79 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 19:30 – 21:40
# Trajet: STNAéroport de Londres Stansted-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 79 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 07:35 – 10:00
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 25min
# Prix: 79 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 19:30 – 21:40
# Trajet: STNAéroport de Londres Stansted-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 81 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 19:30 – 21:40
# Trajet: STNAéroport de Londres Stansted-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 10min
# Prix: 81 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires: 07:35 – 10:00
# Trajet: LGWAéroport de Londres-Gatwick-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 25min
# Prix: 81 €
# Type de voyage: Standard
# Compagnie de vol: easyJet
# ========================================
# done
# Début scrape des villes LON et BRU pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 17:50 – 19:55
# Trajet: LHRAéroport de Londres-Heathrow-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 1h 05min
# Prix: 135 €
# Type de voyage: Economy Light
# Compagnie de vol: Brussels Airlines
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet:
# Temps de trajet: 4h 25min
# Prix: 89 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 06:16 – 09:12
# Trajet: LONSaint-Pancras-BRUMidi
# Type de trajet: 0 changement
# Temps de trajet: 1h 56min
# Prix: 112 €
# Type de voyage:
# Compagnie de vol: Eurostar
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 4h 25min
# Prix: 112 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet:
# Temps de trajet: 4h 25min
# Prix: 112 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# done
# Horaires: 11:25 – 20:35
# Trajet: LGWAéroport de Londres-Gatwick-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 112 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 4h 25min
# Prix: 118 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 11:25 – 20:35
# Trajet: LGWAéroport de Londres-Gatwick-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 118 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 4h 25min
# Prix: 121 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 4h 25min
# Prix: 121 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 11:25 – 20:35
# Trajet: LGWAéroport de Londres-Gatwick-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 121 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 11:25 – 20:35
# Trajet: LGWAéroport de Londres-Gatwick-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 121 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 20:35
# Trajet: STNAéroport de Londres Stansted-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 4h 25min
# Prix: 122 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Luxair
# ========================================
# done
# Horaires: 11:25 – 20:35
# Trajet: LGWAéroport de Londres-Gatwick-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 122 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Luxair
# ========================================
# done
# Horaires: 13:45 – 21:40
# Trajet: LTNAéroport de Londres Luton-CRLAéroport de Charleroi-Bruxelles-Sud
# Type de trajet: direct
# Temps de trajet: 6h 55min
# Prix: 123 €
# Type de voyage: Value, Basic Economy
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 17:50 – 19:55
# Trajet: LHRAéroport de Londres-Heathrow-BRUAéroport de Bruxelles-National
# Type de trajet: direct
# Temps de trajet: 1h 05min
# Prix: 130 €
# Type de voyage: Economy Light
# Compagnie de vol: Brussels Airlines
# ========================================
# done
# Début scrape des villes LON et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 21:45 – 23:00
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 31 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 17:40 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 31 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 15:10 – 16:30
# Trajet: STNAéroport de Londres Stansted-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 31 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 17:40 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 31 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 17:40 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 31 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 10:00 – 11:15
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 49 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 21:45 – 23:00
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 49 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 07:45 – 09:05
# Trajet: STNAéroport de Londres Stansted-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 49 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 21:45 – 23:00
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 52 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 06:20 – 07:40
# Trajet: STNAéroport de Londres Stansted-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 52 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 17:40 – 19:00
# Trajet: LGWAéroport de Londres-Gatwick-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 52 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 10:00 – 11:15
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 53 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 20:25 – 21:45
# Trajet: LGWAéroport de Londres-Gatwick-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 53 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 15:10 – 16:30
# Trajet: STNAéroport de Londres Stansted-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 53 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, British Airways
# ========================================
# done
# Horaires: 21:45 – 23:00
# Trajet: LTNAéroport de Londres Luton-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 15min
# Prix: 78 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# done
# Début scrape des villes LON et BER pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 13:45 – 21:50
# Trajet: LTNAéroport de Londres Luton-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 7h 05min
# Prix: 80 €
# Type de voyage: Économique
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires: 07:25 – 21:50
# Trajet: STNAéroport de Londres Stansted-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 13h 25min
# Prix: 80 €
# Type de voyage: Value, Standard
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires: 13:45 – 21:50
# Trajet: LTNAéroport de Londres Luton-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 7h 05min
# Prix: 97 €
# Type de voyage: Value, Standard
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes LON et CPH pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 06:20 – 09:05
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 72 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 06:20 – 09:05
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 70 €
# Type de voyage: Value
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 08:35 – 16:55
# Trajet: LTNAéroport de Londres Luton-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 7h 20min
# Prix: 71 €
# Type de voyage: Économique, Value
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 17:55 – 07:35+1
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 12h 40min
# Prix: 76 €
# Type de voyage: Value
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 14:05 – 16:55
# Trajet: LGWAéroport de Londres-Gatwick-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 50min
# Prix: 79 €
# Type de voyage: LowFare, Value
# Compagnie de vol: Norwegian, Ryanair
# ========================================
# done
# Horaires: 11:25 – 14:15
# Trajet: LGWAéroport de Londres-Gatwick-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 50min
# Prix: 79 €
# Type de voyage: LowFare, Value
# Compagnie de vol: Norwegian, Ryanair
# ========================================
# done
# Horaires: 06:20 – 09:05
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 80 €
# Type de voyage: Value, Standard
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires: 08:35 – 16:55
# Trajet: LTNAéroport de Londres Luton-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 7h 20min
# Prix: 81 €
# Type de voyage: Économique, Standard
# Compagnie de vol: Wizz Air, easyJet
# ========================================
# done
# Horaires: 17:55 – 07:35+1
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 12h 40min
# Prix: 82 €
# Type de voyage: Value, Standard
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 07:00 – 09:50
# Trajet: LGWAéroport de Londres-Gatwick-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 50min
# Prix: 85 €
# Type de voyage: Standard, Value
# Compagnie de vol: easyJet, Ryanair
# ========================================
# done
# Horaires: 06:20 – 09:05
# Trajet: STNAéroport de Londres Stansted-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 86 €
# Type de voyage: Value, LowFare
# Compagnie de vol: Ryanair, Norwegian
# ...
# Compagnie de vol: easyJet, Wizz Air UK
# ========================================
# done
# Horaires: 09:30 – 19:05
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TIAAéroport Intl de Tirana
# Type de trajet:
# Temps de trajet: 9h 35min
# Prix: 129 €
# Type de voyage: Standard
# Compagnie de vol: easyJet, Ryanair UK
# ========================================
# done
# Horaires: 09:30 – 19:05
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TIAAéroport Intl de Tirana
# Type de trajet:
# Temps de trajet: 9h 35min
# Prix: 130 €
# Type de voyage: Standard
# Compagnie de vol: easyJet, Ryanair UK
# ========================================
# done
# Horaires: 07:45 – 19:05
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TIAAéroport Intl de Tirana
# Type de trajet:
# Temps de trajet: 11h 20min
# Prix: 130 €
# Type de voyage: Standard
# Compagnie de vol: easyJet, Ryanair UK
# ========================================
# done
# Horaires: 13:10 – 22:30
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TIAAéroport Intl de Tirana
# Type de trajet:
# Temps de trajet: 9h 20min
# Prix: 131 €
# Type de voyage: Standard
# Compagnie de vol: easyJet, Wizz Air UK
# ========================================
# done
# Début scrape des villes AMS et SKP pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 20:45 – 01:40+1
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 223 €
# Type de voyage: Économique
# Compagnie de vol: Air Serbia
# ========================================
# done
# Horaires: 08:45 – 16:40
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet:
# Temps de trajet: 7h 55min
# Prix: 137 €
# Type de voyage: Standard, Économique
# Compagnie de vol: easyJet, Wizz Air
# ========================================
# done
# Horaires: 07:05 – 18:50
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 11h 45min
# Prix: 198 €
# Type de voyage: Standard
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 07:45 – 18:50
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 11h 05min
# Prix: 201 €
# Type de voyage: Standard
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 20:45 – 01:40+1
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 209 €
# Type de voyage: Économique
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:10 – 22:50
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 13h 40min
# Prix: 210 €
# Type de voyage: Standard
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 20:45 – 01:40+1
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 55min
# Prix: 217 €
# Type de voyage: Économique
# Compagnie de vol: Air Serbia
# ========================================
# done
# Horaires: 08:45 – 22:45
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 14h 00min
# Prix: 222 €
# Type de voyage: Standard
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 18:30 – 22:40
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 10min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 08:55 – 13:55
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 07:25 – 13:55
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 6h 30min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 18:30 – 22:40
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 10min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 08:55 – 13:55
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 5h 00min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 14:40 – 22:40
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 8h 00min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 07:25 – 13:55
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 6h 30min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Horaires: 18:30 – 22:40
# Trajet: AMSAéroport d'Amsterdam-Schiphol-SKPAéroport Alexandre-le-Grand de Skopje
# Type de trajet: 1 escale
# Temps de trajet: 4h 10min
# Prix: 228 €
# Type de voyage: Economy Light
# Compagnie de vol: Lufthansa, Austrian Airlines
# ========================================
# done
# Début scrape des villes AMS et TGD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 20:45 – 07:30+1
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TGDAéroport de Podgorica (Titograd)
# Type de trajet: 1 escale
# Temps de trajet: 10h 45min
# Prix: 296 €
# Type de voyage: Économique
# Compagnie de vol: Air Serbia, Austrian Airlines
# ========================================
# done
# Horaires: 20:45 – 07:30+1
# Trajet: AMSAéroport d'Amsterdam-Schiphol-TGDAéroport de Podgorica (Titograd)
# Type de trajet: 1 escale
# Temps de trajet: 10h 45min
# Prix: 230 €
# Type de voyage: Économique
# Compagnie de vol: Air Serbia
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Type de voyage:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes AMS et PRN pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et TLL pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et RIX pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et VNO pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et KIV pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et MSQ pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et KBP pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et TBS pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et EVN pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et BAK pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et ANK pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et ECN pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et MLA pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et VAT pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et MCM pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et REK pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes AMS et WAW pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6752\2371564703.py in <module>
#      29
#      30
# ---> 31         driver = webdriver.Firefox(options=options)
#      32         try:
#      33             driver.get(f'https://www.momondo.fr/flight-search/{ville1}-{ville2}/{start_date.strftime("%Y-%m-%d")}/{end_date.strftime("%Y-%m-%d")}?sort=price_a')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, capabilities, proxy, executable_path, options, service_log_path, service_args, service, desired_capabilities, log_path, keep_alive)
#     195             remote_server_addr=self.service.service_url, ignore_proxy=options._ignore_local_proxy
#     196         )
# --> 197         super().__init__(command_executor=executor, options=options, keep_alive=True)
#     198
#     199         self._is_remote = False
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     286         self._authenticator_id = None
#     287         self.start_client()
# --> 288         self.start_session(capabilities, browser_profile)
#     289
#     290     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     379         w3c_caps = _make_w3c_caps(capabilities)
#     380         parameters = {"capabilities": w3c_caps}
# --> 381         response = self.execute(Command.NEW_SESSION, parameters)
#     382         if "sessionId" not in response:
#     383             response = response["value"]
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     440                 params["sessionId"] = self.session_id
#     441
# --> 442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
#     444             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     292         data = utils.dump_json(params)
#     293         url = f"{self._url}{path}"
# --> 294         return self._request(command_info[0], url, body=data)
#     295
#     296     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     314
#     315         if self.keep_alive:
# --> 316             response = self._conn.request(method, url, body=body, headers=headers)
#     317             statuscode = response.status
#     318         else:
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df.head()
