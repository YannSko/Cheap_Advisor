# %%
 ###https://www.kayak.fr/flights/CDG-MAD/2023-11-22/2023-11-29?sort=bestflight_a

# %% [markdown]
# # kayak.fr

# %% [markdown]
# ## Import

# %%
# Scrappe and Clean
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import pandas as pd
import urllib
import re
import requests
import csv
import time

from selenium.webdriver.common.service import Service
from selenium.webdriver.common.service import Service
from fake_useragent import UserAgent
from urllib3.exceptions import NewConnectionError
import logging
from datetime import datetime, timedelta


import pandas as pd 
import numpy as np 


from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# ## Scrappe

# %%
ua = UserAgent()
user_agent = ua.random

villes = ["PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD","BER",  "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')

all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date = datetime(2023, 11, 28)

# Boucle sur les semaines
while start_date <= end_date_final:
    for i in range(0, len(villes), 2):
        ville1 = villes[i]
        ville2 = villes[i + 1]

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')

                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            time.sleep(10)
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(2)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(2)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')


        for voyage in voyages:
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)

print('Fin du scraping')
# Out:
# Début scrape des villes PAR et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 31 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 44 €
# Compagnie de vol: Ryanair, Vueling
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes MAD et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 62 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 22:00 – 23:35
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 57 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 69 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires: 17:10 – 18:40
# Trajet: MADAéroport de Madrid-Barajas-STNAéroport de Londres Stansted
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 68 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 07:35 – 09:00
# Trajet: MADAéroport de Madrid-Barajas-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 74 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes LIS et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 07:45 – 16:10
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: 1 escale
# Temps de trajet: 7h 25min
# Prix: 133 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 188 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 204 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 175 €
# Compagnie de vol: TAP AIR PORTUGAL
# ========================================
# Horaires: 18:20 – 22:20
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 166 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 17:25 – 21:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 170 €
# Compagnie de vol: Vueling
# ========================================
# Horaires: 13:00 – 17:00
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 181 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 19:30 – 23:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 192 €
# Compagnie de vol: Transavia, Vueling
# ========================================
# Horaires: 08:50 – 12:50
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 00min
# Prix: 201 €
# Compagnie de vol: TAP AIR PORTUGAL, Vueling
# ========================================
# Horaires: 15:25 – 19:35
# Trajet: LISAéroport de Lisbonne - Humberto Delgado-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 3h 10min
# Prix: 218 €
# Compagnie de vol: KLM
# ========================================
# Début scrape des villes BRU et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 09:40 – 10:25
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol: Aer Lingus, Ryanair
# ========================================
# Horaires: 10:15 – 11:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 83 €
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 21:15 – 22:00
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 90 €
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires: 18:55 – 19:40
# Trajet: BRUAéroport de Bruxelles-National-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 150 €
# Compagnie de vol: Aer Lingus
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# Début scrape des villes CPH et OSL pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3.2\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 28
#      24 ville2 = villes[i + 1]
#      26 print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')
# ---> 28 driver = webdriver.Firefox(options=options)
#      29 try:
#      30     driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:60, in WebDriver.__init__(self, options, service, keep_alive)
#      57 options = options if options else Options()
#      59 self.service.path = DriverFinder.get_path(self.service, options)
# ---> 60 self.service.start()
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     ignore_proxy=options._ignore_local_proxy,
#      65     keep_alive=keep_alive,
#      66 )
#      67 super().__init__(command_executor=executor, options=options)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:103, in Service.start(self)
#     101 while True:
#     102     self.assert_process_still_running()
# --> 103     if self.is_connectable():
#     104         break
#     106     count += 1
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\service.py:120, in Service.is_connectable(self)
#     117 def is_connectable(self) -> bool:
#     118     """Establishes a socket connection to determine if the service running
#     119     on the port is accessible."""
# --> 120     return utils.is_connectable(self.port)
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\common\utils.py:101, in is_connectable(port, host)
#      99 socket_ = None
#     100 try:
# --> 101     socket_ = socket.create_connection((host, port), 1)
#     102     result = True
#     103 except _is_connectable_exceptions:
#
# File ~\anaconda3.2\Lib\socket.py:843, in create_connection(address, timeout, source_address, all_errors)
#     841 except error as exc:
#     842     if not all_errors:
# --> 843         exceptions.clear()  # raise only the last error
#     844     exceptions.append(exc)
#     845     if sock is not None:
#
# KeyboardInterrupt:

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import ElementClickInterceptedException

def action_aleatoire(driver):
    actions_possibles = ["scroll", "click_button", "fill_text"]
    action_choisie = random.choice(actions_possibles)

    # Enregistrer la position actuelle de la page
    current_scroll_position = driver.execute_script("return window.pageYOffset;")

    if action_choisie == "scroll":
        # Action aléatoire : Faites défiler la page vers le bas
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    elif action_choisie == "click_button":
        # Action aléatoire : Cliquez sur un élément aléatoire (par exemple, un bouton de tri)
        wait = WebDriverWait(driver, 10)
        elements = wait.until(EC.presence_of_all_elements_located((By.XPATH, ".//button[@class='Iqt3 Iqt3-mod-bold Button-No-Standard-Style Iqt3-mod-variant-outline Iqt3-mod-theme-none Iqt3-mod-shape-rounded-small Iqt3-mod-shape-mod-default Iqt3-mod-spacing-default Iqt3-mod-size-default']")))
        
        if elements:
            random_button = random.choice(elements)
            try:
                random_button.click()
            except ElementClickInterceptedException:
                pass  # Gérer l'exception, par exemple, en ne faisant rien

    elif action_choisie == "fill_text":
        # Action aléatoire : Remplissez un champ de texte (par exemple, une recherche)
        wait = WebDriverWait(driver, 10)
        try:
            search_input = wait.until(EC.visibility_of_element_located((By.XPATH, ".//input[@class='k_my-input']")))
            search_terms = ["Amsterdam", "Brussels", "Dublin", "Berlin", "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Reykjavik", "Moscow", "Warsaw", "Paris", "Rome", "Madrid", "London", "Lisbon", "Prague", "Budapest", "Vienna", "Athens", "Bucharest", "Sofia", "Belgrade", "Zagreb", "Tirana", "Skopje", "Podgorica", "Pristina", "Tallinn", "Riga", "Vilnius", "Chișinău", "Minsk", "Kyiv", "Tbilisi", "Yerevan", "Baku", "Ankara", "Ercan", "Valletta", "Vatican City", "Monaco", "Rimini"]
            random_search_term = random.choice(search_terms)
            search_input.send_keys(random_search_term)
        except Exception as e:
            pass  # Gérer l'exception, par exemple, en ne faisant rien

    # Revenir à la position enregistrée
    driver.execute_script(f"window.scrollTo(0, {current_scroll_position});")

# %%
from itertools import combinations
ua = UserAgent()
user_agent = ua.random

villes = [ "PAR", "ROM", "MAD", "LON", "LIS", "AMS", "BRU", "DUB", "CPH", "OSL","BER", "STO", "HEL", "REK", "MOW", "WAW", "PRG", "BUD", "VIE", "ATH", "BUH", "SOF", "BEG", "ZAG", "TIA", "SKP", "TGD", "PRN", "TLL", "RIX", "VNO", "KIV", "MSQ", "KBP", "KBP", "TBS", "EVN", "BAK", "ANK", "ECN", "MLA", "VAT", "MCM", "RMI"]
options = webdriver.FirefoxOptions()
options.add_argument('--headless')
options.add_argument(f'user-agent={user_agent}')
random_sleep = random.uniform(2, 5)
random_week_sleep = random.uniform(30,45)
all_data = []

logging.basicConfig(filename='scraping.log', level=logging.ERROR)

# Date initiale
start_date = datetime(2023, 11, 22)
end_date = datetime(2023, 11, 28)

# Date finale (2 mois plus tard)
end_date_final = datetime(2024, 1, 22)
city_pairs = list(combinations(villes, 2))
# Boucle sur les semaines
while start_date <= end_date_final:
    for pair in city_pairs:
        ville1, ville2 = pair

        print(f'Début scrape des villes {ville1} et {ville2} pour la semaine du {start_date.strftime("%Y-%m-%d")} au {end_date.strftime("%Y-%m-%d")}')

        driver = webdriver.Firefox(options=options)
        try:
            driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            time.sleep(random_sleep)
                      
        except NewConnectionError:
            logging.error(f'Could not establish connection for cities {ville1} and {ville2}, retrying...')
            
            try:
                driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
            except Exception as e:
                logging.error(f'Failed to scrape cities {ville1} and {ville2}: {e}')
                driver.quit()
                continue
        time.sleep(random_week_sleep)

        # Fonction auxiliaire pour récupérer des données
        def extract_data(element, xpath):
            try:
                data = element.find_element(By.XPATH, xpath).get_attribute('textContent')
            except:
                data = ""
            return data
        time.sleep(random_sleep)
        # Récupérer le contenu des divs JWEO et xdW8 dans c3J0r-container
        # Récupérer le contenu des éléments
        voyages = driver.find_elements(By.XPATH, './/div[contains(@class, "nrc6-inner")]')
        time.sleep(random_sleep)
        action_aleatoire(driver)

        for voyage in voyages:
            time.sleep(5)
        # Récupérer le contenu des éléments pour chaque voyage
            horaires = extract_data(voyage, './/div[@class="vmXl vmXl-mod-variant-large"]')
            trajet = extract_data(voyage, './/div[@class="c_cgF c_cgF-mod-variant-full-airport"]')
            type_trajet = extract_data(voyage, './/span[@class="JWEO-stops-text"]')
            temps_trajet = extract_data(voyage, './/div[@class="xdW8 xdW8-mod-full-airport"]/div[@class="vmXl vmXl-mod-variant-default"]')
            prix = extract_data(voyage, './/div[@class="f8F1-price-text"]')
            type_voyage = extract_data(voyage, './/div[@class="aC3z-name"]')
            Compagnie = extract_data(voyage, './/div[@class="J0g6-operator-text"]')
            action_aleatoire(driver)
        # Imprimer les résultats pour chaque voyage
         
            print("Horaires:", horaires)
            print("Trajet:", trajet)
            print("Type de trajet:", type_trajet)
            print("Temps de trajet:", temps_trajet)
            print("Prix:", prix)
            print("Compagnie de vol:", Compagnie)
            print("========================================")
            data_entry = {"Date_Départ":start_date.strftime("%Y-%m-%d"),"Date_arrivée":end_date.strftime("%Y-%m-%d"),  "VILLE_DEPART": ville1,"VILLE_ARRIVEE": ville2,"Horaires": horaires,"Trajet": trajet,"Type de trajet": type_trajet,"Temps de trajet": temps_trajet,"Prix": prix,"Compagnie de vol": Compagnie}
            time.sleep(random_sleep)
            all_data.append(data_entry)
            SauvCSV = pd.DataFrame( all_data)
            SauvCSV.to_csv('SauvK_b.csv',mode='a',index=True,encoding='utf-8')
            print("done")
        # Fermeture du webdriver
        driver.quit()

    # Passer à la semaine suivante
    start_date += timedelta(weeks=1)
    end_date += timedelta(weeks=1)
df = pd.DataFrame(all_data)
                          # Specify the CSV file path
csv_file = "data_kayak.csv"

# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False)
print('Fin du scraping')
# Out:
# Début scrape des villes PAR et ROM pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 33 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:10 – 11:10
# Trajet: BVAAéroport de Beauvais-Tillé-CIAAéroport de Rome Ciampino
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 31 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et MAD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:10 – 20:20
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 64 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 07:05 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 55 €
# Compagnie de vol: easyJet, Ryanair
# ========================================
# done
# Horaires: 13:15 – 19:25
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 6h 10min
# Prix: 49 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:10 – 20:20
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 59 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 10:55 – 12:55
# Trajet: ORYAéroport de Paris-Orly-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 71 €
# Compagnie de vol: Air Europa, Ryanair
# ========================================
# done
# Horaires: 07:00 – 09:10
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 77 €
# Compagnie de vol: Iberia, Ryanair
# ========================================
# done
# Horaires: 07:05 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 79 €
# Compagnie de vol: easyJet, Air Europa
# ========================================
# done
# Horaires: 07:05 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 79 €
# Compagnie de vol: easyJet, Air Europa
# ========================================
# done
# Horaires: 10:55 – 12:55
# Trajet: ORYAéroport de Paris-Orly-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 89 €
# Compagnie de vol: Air Europa
# ========================================
# done
# Horaires: 18:10 – 20:20
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 85 €
# Compagnie de vol: Ryanair, Air Europa
# ========================================
# done
# Horaires: 10:55 – 12:55
# Trajet: ORYAéroport de Paris-Orly-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 00min
# Prix: 89 €
# Compagnie de vol: Air Europa
# ========================================
# done
# Horaires: 12:45 – 14:55
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 84 €
# Compagnie de vol: Iberia, Ryanair
# ========================================
# done
# Horaires: 18:10 – 20:20
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 85 €
# Compagnie de vol: Ryanair, Air Europa
# ========================================
# done
# Horaires: 10:15 – 12:20
# Trajet: ORYAéroport de Paris-Orly-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 05min
# Prix: 86 €
# Compagnie de vol: Iberia, Ryanair
# ========================================
# done
# Horaires: 12:40 – 14:45
# Trajet: ORYAéroport de Paris-Orly-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 05min
# Prix: 86 €
# Compagnie de vol: Iberia, Ryanair
# ========================================
# done
# Horaires: 07:05 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 86 €
# Compagnie de vol: easyJet, Transavia France
# ========================================
# done
# Horaires: 18:10 – 20:20
# Trajet: BVAAéroport de Beauvais-Tillé-MADAéroport de Madrid-Barajas
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 87 €
# Compagnie de vol: Ryanair, Transavia France
# ========================================
# done
# Début scrape des villes PAR et LON pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:25 – 18:30
# Trajet: ORYAéroport de Paris-Orly-LGWAéroport de Londres-Gatwick
# Type de trajet: direct
# Temps de trajet: 1h 05min
# Prix: 68 €
# Compagnie de vol: Vueling
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et LIS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 33 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 31 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 38 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 44 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires: 06:30 – 08:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 45 €
# Compagnie de vol: Vueling, Ryanair
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 46 €
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 16:35 – 18:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 49 €
# Compagnie de vol: Vueling, Ryanair
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 52 €
# Compagnie de vol: Ryanair, Vueling
# ========================================
# done
# Horaires: 06:30 – 08:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 53 €
# Compagnie de vol: Vueling, Ryanair
# ========================================
# done
# Horaires: 16:35 – 18:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 57 €
# Compagnie de vol: Vueling, Ryanair
# ========================================
# done
# Horaires: 06:30 – 08:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 58 €
# Compagnie de vol: Vueling
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 61 €
# Compagnie de vol: Ryanair, TAP AIR PORTUGAL
# ========================================
# done
# Horaires: 18:30 – 20:00
# Trajet: BVAAéroport de Beauvais-Tillé-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 30min
# Prix: 61 €
# Compagnie de vol: Ryanair, TAP AIR PORTUGAL
# ========================================
# done
# Horaires: 16:35 – 18:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 62 €
# Compagnie de vol: Vueling
# ========================================
# done
# Horaires: 06:30 – 08:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 65 €
# Compagnie de vol: Vueling, easyJet
# ========================================
# done
# Horaires: 06:30 – 08:10
# Trajet: ORYAéroport de Paris-Orly-LISAéroport de Lisbonne - Humberto Delgado
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 63 €
# Compagnie de vol: Vueling
# ========================================
# done
# Début scrape des villes PAR et AMS pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:30 – 15:50
# Trajet: CDGAéroport Charles-de-Gaulle-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 135 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 14:30 – 15:50
# Trajet: CDGAéroport Charles-de-Gaulle-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 134 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 09:00 – 14:10
# Trajet: BVAAéroport de Beauvais-Tillé-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet:
# Temps de trajet: 5h 10min
# Prix: 90 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 14:30 – 15:50
# Trajet: CDGAéroport Charles-de-Gaulle-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 20min
# Prix: 134 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 09:30 – 11:00
# Trajet: CDGAéroport Charles-de-Gaulle-AMSAéroport d'Amsterdam-Schiphol
# Type de trajet: direct
# Temps de trajet: 1h 30min
# Prix: 135 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et BRU pour la semaine du 2023-11-22 au 2023-11-28
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 20:21 – 21:45
# Trajet: PARGare du Nord-BRUMidi
# Type de trajet: 0 changement
# Temps de trajet: 1h 24min
# Prix: 88 €
# Compagnie de vol: Eurostar
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et DUB pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:00 – 09:40
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 29 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:00 – 09:40
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 09:00 – 09:40
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:05 – 18:45
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 18:05 – 18:45
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 28 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 09:00 – 09:40
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 58 €
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# done
# Horaires: 18:05 – 18:45
# Trajet: BVAAéroport de Beauvais-Tillé-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 40min
# Prix: 58 €
# Compagnie de vol: Ryanair, Aer Lingus
# ========================================
# done
# Horaires: 10:05 – 10:55
# Trajet: CDGAéroport Charles-de-Gaulle-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 50min
# Prix: 58 €
# Compagnie de vol: Aer Lingus, Ryanair
# ========================================
# done
# Horaires: 10:05 – 10:55
# Trajet: CDGAéroport Charles-de-Gaulle-DUBAéroport de Dublin
# Type de trajet: direct
# Temps de trajet: 1h 50min
# Prix: 58 €
# Compagnie de vol: Aer Lingus, Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et CPH pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 10:15 – 17:30
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 141 €
# Compagnie de vol: Brussels Airlines, SWISS
# ========================================
# done
# Horaires: 15:05 – 17:00
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 191 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 10:15 – 17:30
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: 1 escale
# Temps de trajet: 7h 15min
# Prix: 136 €
# Compagnie de vol: Brussels Airlines, SWISS
# ========================================
# done
# Horaires: 15:05 – 17:00
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 191 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 15:05 – 17:00
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 191 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 15:05 – 17:00
# Trajet: CDGAéroport Charles-de-Gaulle-CPHAéroport de Copenhague Kastrup
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 199 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et OSL pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:05 – 16:25
# Trajet: CDGAéroport Charles-de-Gaulle-OSLAéroport d'Oslo-Gardermoen
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 139 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 14:05 – 16:25
# Trajet: CDGAéroport Charles-de-Gaulle-OSLAéroport d'Oslo-Gardermoen
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 137 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 13:45 – 18:35
# Trajet: BVAAéroport de Beauvais-Tillé-TRFAéroport de Sandefjord, Torp
# Type de trajet:
# Temps de trajet: 4h 50min
# Prix: 87 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 20:50 – 23:15
# Trajet: CDGAéroport Charles-de-Gaulle-OSLAéroport d'Oslo-Gardermoen
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 137 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 14:05 – 16:25
# Trajet: CDGAéroport Charles-de-Gaulle-OSLAéroport d'Oslo-Gardermoen
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 137 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 20:50 – 23:15
# Trajet: CDGAéroport Charles-de-Gaulle-OSLAéroport d'Oslo-Gardermoen
# Type de trajet: direct
# Temps de trajet: 2h 25min
# Prix: 137 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et BER pour la semaine du 2023-11-22 au 2023-11-28
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 06:40 – 08:25
# Trajet: ORYAéroport de Paris-Orly-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 110 €
# Compagnie de vol: easyJet
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 07:25 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 122 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 13:05 – 14:50
# Trajet: CDGAéroport Charles-de-Gaulle-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 127 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 07:25 – 09:20
# Trajet: CDGAéroport Charles-de-Gaulle-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 126 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 13:05 – 14:50
# Trajet: CDGAéroport Charles-de-Gaulle-BERAéroport de Berlin Brandebourg
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 136 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et STO pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:25 – 12:00
# Trajet: CDGAéroport Charles-de-Gaulle-ARNAéroport de Stockholm-Arlanda
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 154 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 09:25 – 12:00
# Trajet: CDGAéroport Charles-de-Gaulle-ARNAéroport de Stockholm-Arlanda
# Type de trajet: direct
# Temps de trajet: 2h 35min
# Prix: 153 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 15:15 – 17:55
# Trajet: CDGAéroport Charles-de-Gaulle-ARNAéroport de Stockholm-Arlanda
# Type de trajet: direct
# Temps de trajet: 2h 40min
# Prix: 153 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et HEL pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 14:35 – 18:25
# Trajet: BVAAéroport de Beauvais-Tillé-HELAéroport de Vantaa
# Type de trajet: direct
# Temps de trajet: 2h 50min
# Prix: 154 €
# Compagnie de vol: Ryanair, Lufthansa
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 14:35 – 18:25
# Trajet: BVAAéroport de Beauvais-Tillé-HELAéroport de Vantaa
# Type de trajet: direct
# Temps de trajet: 2h 50min
# Prix: 113 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 12:35 – 16:40
# Trajet: CDGAéroport Charles-de-Gaulle-HELAéroport de Vantaa
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 187 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 19:30 – 23:35
# Trajet: CDGAéroport Charles-de-Gaulle-HELAéroport de Vantaa
# Type de trajet: direct
# Temps de trajet: 3h 05min
# Prix: 187 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et REK pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 11:30 – 14:10
# Trajet: CDGAéroport Charles-de-Gaulle-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 3h 40min
# Prix: 224 €
# Compagnie de vol: PLAY
# ========================================
# done
# Horaires: 11:30 – 14:10
# Trajet: CDGAéroport Charles-de-Gaulle-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 3h 40min
# Prix: 213 €
# Compagnie de vol: PLAY
# ========================================
# done
# Horaires: 08:25 – 19:45
# Trajet: BVAAéroport de Beauvais-Tillé-KEFKeflavik Intl
# Type de trajet:
# Temps de trajet: 12h 20min
# Prix: 116 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 11:30 – 14:10
# Trajet: CDGAéroport Charles-de-Gaulle-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 3h 40min
# Prix: 273 €
# Compagnie de vol: PLAY, Transavia France
# ========================================
# done
# Horaires: 13:05 – 15:50
# Trajet: CDGAéroport Charles-de-Gaulle-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 3h 45min
# Prix: 306 €
# Compagnie de vol: Icelandair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 13:05 – 15:50
# Trajet: CDGAéroport Charles-de-Gaulle-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 3h 45min
# Prix: 384 €
# Compagnie de vol: Icelandair, PLAY
# ========================================
# done
# Début scrape des villes PAR et MOW pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes PAR et WAW pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 09:20 – 11:35
# Trajet: BVAAéroport de Beauvais-Tillé-WMIAéroport de Mazovie Varsovie-Modlin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 57 €
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 09:20 – 11:35
# Trajet: BVAAéroport de Beauvais-Tillé-WMIAéroport de Mazovie Varsovie-Modlin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 55 €
# Compagnie de vol: Ryanair, Wizz Air
# ========================================
# done
# Horaires: 09:50 – 12:10
# Trajet: ORYAéroport de Paris-Orly-WAWAéroport de Varsovie-Chopin
# Type de trajet: direct
# Temps de trajet: 2h 20min
# Prix: 106 €
# Compagnie de vol: Wizz Air
# ========================================
# done
# Horaires: 09:20 – 11:35
# Trajet: BVAAéroport de Beauvais-Tillé-WMIAéroport de Mazovie Varsovie-Modlin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 76 €
# Compagnie de vol: Ryanair, easyJet
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 09:20 – 11:35
# Trajet: BVAAéroport de Beauvais-Tillé-WMIAéroport de Mazovie Varsovie-Modlin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 79 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 09:20 – 11:35
# Trajet: BVAAéroport de Beauvais-Tillé-WMIAéroport de Mazovie Varsovie-Modlin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 176 €
# Compagnie de vol: Ryanair, LOT
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 10:50 – 13:05
# Trajet: CDGAéroport Charles-de-Gaulle-WAWAéroport de Varsovie-Chopin
# Type de trajet: direct
# Temps de trajet: 2h 15min
# Prix: 185 €
# Compagnie de vol: LOT
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et PRG pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 15:00 – 16:45
# Trajet: CDGAéroport Charles-de-Gaulle-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 106 €
# Compagnie de vol: Smartwings, Vueling
# ========================================
# done
# Horaires: 15:00 – 16:45
# Trajet: CDGAéroport Charles-de-Gaulle-PRGAéroport de Prague-Václav-Havel
# Type de trajet: direct
# Temps de trajet: 1h 45min
# Prix: 96 €
# Compagnie de vol: Smartwings, Vueling
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et BUD pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 17:35 – 19:45
# Trajet: BVAAéroport de Beauvais-Tillé-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 64 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 17:35 – 19:45
# Trajet: BVAAéroport de Beauvais-Tillé-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 63 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires: 13:05 – 15:15
# Trajet: ORYAéroport de Paris-Orly-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 85 €
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires: 17:35 – 19:45
# Trajet: BVAAéroport de Beauvais-Tillé-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 90 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 13:05 – 15:15
# Trajet: ORYAéroport de Paris-Orly-BUDAéroport de Budapest-Ferenc Liszt
# Type de trajet: direct
# Temps de trajet: 2h 10min
# Prix: 111 €
# Compagnie de vol: Wizz Air, Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes PAR et VIE pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 21:00 – 22:55
# Trajet: CDGAéroport Charles-de-Gaulle-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 156 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 21:00 – 22:55
# Trajet: CDGAéroport Charles-de-Gaulle-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 155 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires: 07:00 – 11:50
# Trajet: ORYAéroport de Paris-Orly-VIEAéroport de Vienne-Schwechat
# Type de trajet:
# Temps de trajet: 4h 50min
# Prix: 118 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 07:10 – 09:05
# Trajet: CDGAéroport Charles-de-Gaulle-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 168 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 07:10 – 09:05
# Trajet: CDGAéroport Charles-de-Gaulle-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 168 €
# Compagnie de vol: Austrian Airlines
# ========================================
# done
# Horaires: 21:00 – 22:55
# Trajet: CDGAéroport Charles-de-Gaulle-VIEAéroport de Vienne-Schwechat
# Type de trajet: direct
# Temps de trajet: 1h 55min
# Prix: 169 €
# Compagnie de vol: Air France
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# ...
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes ROM et STO pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 13:15 – 17:45
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-ARNAéroport de Stockholm-Arlanda
# Type de trajet: 1 escale
# Temps de trajet: 4h 30min
# Prix: 204 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes ROM et HEL pour la semaine du 2023-11-22 au 2023-11-28
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 06:30 – 18:25
# Trajet: CIAAéroport de Rome Ciampino-HELAéroport de Vantaa
# Type de trajet:
# Temps de trajet: 10h 55min
# Prix: 130 €
# Compagnie de vol: Ryanair
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires: 17:15 – 00:05+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 5h 50min
# Prix: 186 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 17:15 – 00:05+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 5h 50min
# Prix: 186 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 17:25
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 186 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 17:25
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 186 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 17:15 – 00:05+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 5h 50min
# Prix: 195 €
# Compagnie de vol: KLM, Air France
# ========================================
# done
# Horaires: 17:15 – 00:05+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 5h 50min
# Prix: 199 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 10:00 – 17:25
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 195 €
# Compagnie de vol: KLM, Air France
# ========================================
# done
# Horaires: 10:00 – 17:25
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 6h 25min
# Prix: 199 €
# Compagnie de vol: KLM
# ========================================
# done
# Horaires: 18:40 – 01:00+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 5h 20min
# Prix: 240 €
# Compagnie de vol: Lufthansa
# ========================================
# done
# Horaires: 15:40 – 23:35
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-HELAéroport de Vantaa
# Type de trajet: 1 escale
# Temps de trajet: 6h 55min
# Prix: 210 €
# Compagnie de vol: Air France, KLM
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes ROM et REK pour la semaine du 2023-11-22 au 2023-11-28
# Horaires: 20:35 – 10:40+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: 1 escale
# Temps de trajet: 15h 05min
# Prix: 398 €
# Compagnie de vol: British Airways, Wizz Air Malta
# ========================================
# done
# Horaires: 06:00 – 14:00
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 9h 00min
# Prix: 185 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:05 – 19:45
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet:
# Temps de trajet: 14h 40min
# Prix: 122 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:00 – 17:50
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 12h 50min
# Prix: 149 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:50 – 17:00
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 8h 10min
# Prix: 213 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:05 – 19:45
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 14h 40min
# Prix: 145 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 21:50 – 09:30+1
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 12h 40min
# Prix: 154 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 06:00 – 14:00
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet:
# Temps de trajet: 9h 00min
# Prix: 169 €
# Compagnie de vol: Ryanair, PLAY
# ========================================
# done
# Horaires: 23:05 – 09:30+1
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 11h 25min
# Prix: 168 €
# Compagnie de vol: Wizz Air UK, Wizz Air Malta
# ========================================
# done
# Horaires: 06:50 – 17:50
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 12h 00min
# Prix: 164 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 10:00 – 19:15
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 10h 15min
# Prix: 193 €
# Compagnie de vol: ITA Airways, Wizz Air Malta
# ========================================
# done
# Horaires: 08:40 – 17:00
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 9h 20min
# Prix: 205 €
# Compagnie de vol: Wizz Air, Wizz Air Malta
# ========================================
# done
# Horaires: 09:20 – 19:15
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 10h 55min
# Prix: 188 €
# Compagnie de vol: Aeroitalia, Wizz Air Malta
# ========================================
# done
# Horaires: 08:25 – 14:25
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 7h 00min
# Prix: 374 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 20:50 – 09:30+1
# Trajet: CIAAéroport de Rome Ciampino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 13h 40min
# Prix: 162 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Horaires: 09:20 – 19:15
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 10h 55min
# Prix: 204 €
# Compagnie de vol: Air Connect, Wizz Air Malta
# ========================================
# done
# Horaires: 06:50 – 17:10
# Trajet: FCOAéroport Léonard-de-Vinci de Rome Fiumicino-KEFKeflavik Intl
# Type de trajet: direct
# Temps de trajet: 11h 20min
# Prix: 193 €
# Compagnie de vol: Plusieurs compagnies
# ========================================
# done
# Début scrape des villes ROM et MOW pour la semaine du 2023-11-22 au 2023-11-28
# Début scrape des villes ROM et WAW pour la semaine du 2023-11-22 au 2023-11-28
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Horaires:
# Trajet:
# Type de trajet:
# Temps de trajet:
# Prix:
# Compagnie de vol:
# ========================================
# done
# Début scrape des villes ROM et PRG pour la semaine du 2023-11-22 au 2023-11-28
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[3], line 30
#      28 driver = webdriver.Firefox(options=options)
#      29 try:
# ---> 30     driver.get(f'https://www.kayak.fr/flights/{ville1}-{ville2}/{start_date}/{end_date}?sort=bestflight_a')
#      31     time.sleep(10)
#      33 except NewConnectionError:
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\webdriver.py:353, in WebDriver.get(self, url)
#     351 def get(self, url: str) -> None:
#     352     """Loads a web page in the current browser session."""
# --> 353     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~\anaconda3.2\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: Reached error page: about:neterror?e=connectionFailure&u=https%3A//www.kayak.fr/flights/ROM-PRG/2023-11-22%252000%3A00%3A00/2023-11-28%252000%3A00%3A00%3Fsort%3Dbestflight_a&c=UTF-8&d=Firefox%20ne%20peut%20%C3%A9tablir%20de%20connexion%20avec%20le%20serveur%20%C3%A0%20l%E2%80%99adresse%20www.kayak.fr.
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:189:5
# UnknownError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:768:5
# checkReadyState@chrome://remote/content/marionette/navigate.sys.mjs:58:24
# onNavigation@chrome://remote/content/marionette/navigate.sys.mjs:324:39
# emit@resource://gre/modules/EventEmitter.sys.mjs:154:20
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteEventsParent.sys.mjs:33:25
